# %%
import pymysql as py
import pandas as pd

# %%
conn = py.connect(user = 'root',host = 'localhost',password = '23032001Rk1@',autocommit = True,database = 'demo')
cur = conn.cursor()
q= 'select * from smartphones'
cur.execute(q)
rows = cur.fetchall()
col = list(map(lambda x:x[0],cur.description))
df = pd.DataFrame(rows,columns = col)
conn.close()

# %%
df
# Out:
#     brand_name                            model  price  rating has_5g has_nfc  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0   True    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0   True   False
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0   True   False
# 3     motorola             Motorola Moto G62 5G  14999    81.0   True   False
# 4       realme               Realme 10 Pro Plus  24999    82.0   True   False
# ..         ...                              ...    ...     ...    ...     ...
# 822       oppo                     Oppo Find X6  69990    89.0   True    True
# 823   motorola       Motorola Moto Edge S30 Pro  34990    83.0   True   False
# 824      honor                      Honor X8 5G  14990    75.0   True   False
# 825       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0   True    True
# 826   motorola             Motorola Moto G91 5G  19990    80.0   True    True
#
# ...

# %% [markdown]
# # pyodbc

# %%
import pyodbc as pb

# %%
conn = pb.connect('Driver={SQL Server};'
                 'Server=DESKTOP-ARGAQDT\SQLEXPRESS;'
                 'Database=superstor;'
                 'Trusted_Connection=yes;')
cur = conn.cursor()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# <>:2: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_13400\969086361.py:2: SyntaxWarning: invalid escape sequence '\S'
#   'Server=DESKTOP-ARGAQDT\SQLEXPRESS;'

# %%
cur.execute('select * from HR')
rows = cur.fetchall()
rows = [tuple(i) for i in rows]
col = list(map(lambda x:x[0],cur.description))
df = pd.DataFrame(rows,columns = col)
conn.close()

# %%
df
# Out:
#           EmpID  Age AgeGroup  Attrition     BusinessTravel  DailyRate  \
# 0      297.0000   18    18-25       True      Travel_Rarely        230
# 1      302.0000   18    18-25      False      Travel_Rarely        812
# 2      458.0000   18    18-25       True  Travel_Frequently       1306
# 3      728.0000   18    18-25      False         Non-Travel        287
# 4      829.0000   18    18-25       True         Non-Travel        247
# ...         ...  ...      ...        ...                ...        ...
# 1475   412.0000   60      55+      False      Travel_Rarely        422
# 1476   428.0000   60      55+      False  Travel_Frequently       1499
# 1477   537.0000   60      55+      False      Travel_Rarely       1179
# 1478   880.0000   60      55+      False      Travel_Rarely        696
# 1479  1210.0000   60      55+      False      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  ...  \
# ...
