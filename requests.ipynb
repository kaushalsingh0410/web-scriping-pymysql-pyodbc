# %%
import requests as r
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = '''https://www.flipkart.com/search?q=watch+for+men&sid=r18%2Cf13&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&as-pos=1&as-type=RECENT&suggestionId=watch+for+men%7CWrist+Watches&requestId=33157cb6-d5d2-49b8-8d88-9ba04204758a&as-backfill=on'''

# %%
data = r.get(url)

# %%
html = data.text

# %%
soup = BeautifulSoup(html,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
for i in soup.find_all('div',{'class':'_2B099V'}):
    print(i.text)
# Out:
# SponsoredUnltd.Analog Watch  - For Men UNG030001₹6,497₹12,99550% off
# SponsoredUnltd.Analog Watch  - For Men UNG010001₹5,997₹11,99550% off
# Blue PearlAnalog Watch  - For Men Combo Pack Of 2 New Arrival Bla...₹219₹1,49985% off
# TIMEXAnalog Watch  - For Men TW0TG7303₹599₹1,49960% off
# PROVOGUESports Formal Casual Series Analog Watch  - For Men SK-...₹299₹2,49988% off
# SONATAPlastic Analog Watch  - For Men NP77085PP02W₹435₹72540% off
# exactorTrending Day & Date Functioning Black Dial Watch for Bo...₹349₹89961% off
# SponsoredUnltd.Multifunction Blue Dial Analog Watch  - For Men UNG0200...₹5,997₹11,99550% off
# Allen SollyAnalog Watch  - For Men AS000010E₹1,220₹2,92258% off
# FastrackAnalog Watch  - For Men 3240SL02₹1,152₹2,09545% off
# SponsoredUnltd.Analog Watch  - For Men UNG030002₹6,997₹13,99550% off
# SponsoredTIMEWEARTIMEWEAR Slim Series Two Hands Brown Leather Strap Anal...₹339₹2,19984% off
# CASADOBranded Bracelet | Gold Plated | Studded | 3D Cut Glass...₹398₹2,99986% off
# ...
